# %% [markdown]
# # Predict Using the pretrained model

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

# %%
tokenizer = AutoTokenizer.from_pretrained("CLTL/gm-ner-xlmrbase")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# XLMRobertaForTokenClassification LOAD REPORT from: CLTL/gm-ner-xlmrbase
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
pipe = pipeline("ner", model="CLTL/gm-ner-xlmrbase", tokenizer=tokenizer, aggregation_strategy="simple")
# Out:
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# XLMRobertaForTokenClassification LOAD REPORT from: CLTL/gm-ner-xlmrbase
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
text = "Morgen te half twee sal een gecomomeerao elgemesne vergadering van de commissie en van do directeuren dor Maatschappij ter bevordering van het natuurkundig onderzoek der Nederlandsche Koloniën worden gehouden te Amsterdam ln Artia (Ingang : Plantage Mlddellaan). Tot de punten van behandeling behooren: 4o. Medodeelingen omtrent de uitkomsten der Siboga-expeditle, met demonstratie, door professor Max Weber. bo. Ulteenietting van snkels resultaten, die tydens de Siboga-expeditie op hydrographlsch gebied verkregen zyn door den heer Tydeman, kaplteln-luitenant ter zee."
pipe(text)
# Out:
# [{'entity': 'B-ORG',
#   'score': np.float32(0.9331381),
#   'index': 28,
#   'word': '▁Ma',
#   'start': 106,
#   'end': 108},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.75513464),
#   'index': 29,
#   'word': 'at',
#   'start': 108,
#   'end': 110},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.90971434),
#   'index': 30,
#   'word': 'schap',
#   'start': 110,
#   'end': 115},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.92971486),
#   'index': 31,
#   'word': 'pij',
#   'start': 115,
#   'end': 118},
#  {'entity': 'B-LOCderiv',
#   'score': np.float32(0.98924106),
#   'index': 41,
#   'word': '▁Nederland',
#   'start': 170,
#   'end': 179},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.7251218),
#   'index': 43,
#   'word': '▁Kolon',
#   'start': 184,
#   'end': 189},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9270144),
#   'index': 44,
#   'word': 'i',
#   'start': 189,
#   'end': 190},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.56881446),
#   'index': 45,
#   'word': 'ën',
#   'start': 190,
#   'end': 192},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.9962135),
#   'index': 49,
#   'word': '▁Amsterdam',
#   'start': 212,
#   'end': 221},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.9669281),
#   'index': 52,
#   'word': '▁Arti',
#   'start': 225,
#   'end': 229},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.86968493),
#   'index': 53,
#   'word': 'a',
#   'start': 229,
#   'end': 230},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.49498612),
#   'index': 58,
#   'word': '▁Plan',
#   'start': 241,
#   'end': 245},
#  {'entity': 'I-SHP',
#   'score': np.float32(0.5482373),
#   'index': 59,
#   'word': 'tage',
#   'start': 245,
#   'end': 249},
#  {'entity': 'I-SHP',
#   'score': np.float32(0.5992009),
#   'index': 60,
#   'word': '▁M',
#   'start': 250,
#   'end': 251},
#  {'entity': 'I-SHP',
#   'score': np.float32(0.7197953),
#   'index': 61,
#   'word': 'ld',
#   'start': 251,
#   'end': 253},
#  {'entity': 'I-SHP',
#   'score': np.float32(0.703424),
#   'index': 62,
#   'word': 'della',
#   'start': 253,
#   'end': 258},
#  {'entity': 'I-SHP',
#   'score': np.float32(0.6974996),
#   'index': 63,
#   'word': 'an',
#   'start': 258,
#   'end': 260},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.5433163),
#   'index': 87,
#   'word': '▁Si',
#   'start': 347,
#   'end': 349},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.7895075),
#   'index': 88,
#   'word': 'boga',
#   'start': 349,
#   'end': 353},
#  {'entity': 'B-PER',
#   'score': np.float32(0.99647695),
#   'index': 100,
#   'word': '▁Max',
#   'start': 398,
#   'end': 401},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99776566),
#   'index': 101,
#   'word': '▁Web',
#   'start': 402,
#   'end': 405},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9944437),
#   'index': 102,
#   'word': 'er',
#   'start': 405,
#   'end': 407},
#  {'entity': 'B-LOC',
#   'score': np.float32(0.5666777),
#   'index': 120,
#   'word': '▁Si',
#   'start': 464,
#   'end': 466},
#  {'entity': 'I-LOC',
#   'score': np.float32(0.82173115),
#   'index': 121,
#   'word': 'boga',
#   'start': 466,
#   'end': 470},
#  {'entity': 'B-PER',
#   'score': np.float32(0.99341375),
#   'index': 140,
#   'word': '▁Ty',
#   'start': 534,
#   'end': 536},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9908652),
#   'index': 141,
#   'word': 'de',
#   'start': 536,
#   'end': 538},
#  {'entity': 'I-PER',
#   'score': np.float32(0.98856235),
#   'index': 142,
#   'word': 'man',
#   'start': 538,
#   'end': 541}]

# %%
tokenizer.tokenize(text)
# Out:
# ['▁Morgen',
#  '▁te',
#  '▁half',
#  '▁twee',
#  '▁sal',
#  '▁een',
#  '▁ge',
#  'com',
#  'ome',
#  'era',
#  'o',
#  '▁el',
#  'geme',
#  's',
#  'ne',
#  '▁',
#  'vergadering',
#  '▁van',
#  '▁de',
#  '▁',
#  'commissie',
#  '▁en',
#  '▁van',
#  '▁do',
#  '▁directeur',
#  'en',
#  '▁dor',
#  '▁Ma',
#  'at',
#  'schap',
#  'pij',
#  '▁ter',
#  '▁bevorder',
#  'ing',
#  '▁van',
#  '▁het',
#  '▁natuur',
#  'kundig',
#  '▁onderzoek',
#  '▁der',
#  '▁Nederland',
#  'sche',
#  '▁Kolon',
#  'i',
#  'ën',
#  '▁worden',
#  '▁gehouden',
#  '▁te',
#  '▁Amsterdam',
#  '▁l',
#  'n',
#  '▁Arti',
#  'a',
#  '▁(',
#  'In',
#  'gang',
#  '▁:',
#  '▁Plan',
#  'tage',
#  '▁M',
#  'ld',
#  'della',
#  'an',
#  ').',
#  '▁Tot',
#  '▁de',
#  '▁punten',
#  '▁van',
#  '▁behandeling',
#  '▁be',
#  'hoor',
#  'en',
#  ':',
#  '▁4',
#  'o',
#  '.',
#  '▁Med',
#  'o',
#  'deel',
#  'ingen',
#  '▁omtrent',
#  '▁de',
#  '▁uit',
#  'komst',
#  'en',
#  '▁der',
#  '▁Si',
#  'boga',
#  '-',
#  'exp',
#  'edit',
#  'le',
#  ',',
#  '▁met',
#  '▁demonstrat',
#  'ie',
#  ',',
#  '▁door',
#  '▁professor',
#  '▁Max',
#  '▁Web',
#  'er',
#  '.',
#  '▁bo',
#  '.',
#  '▁Ul',
#  'te',
#  'enie',
#  'tting',
#  '▁van',
#  '▁s',
#  'n',
#  'kel',
#  's',
#  '▁resultaten',
#  ',',
#  '▁die',
#  '▁tydens',
#  '▁de',
#  '▁Si',
#  'boga',
#  '-',
#  'ex',
#  'pedi',
#  'tie',
#  '▁op',
#  '▁hydro',
#  'graph',
#  'l',
#  'sch',
#  '▁gebied',
#  '▁verk',
#  're',
#  'gen',
#  '▁z',
#  'yn',
#  '▁door',
#  '▁den',
#  '▁heer',
#  '▁Ty',
#  'de',
#  'man',
#  ',',
#  '▁ka',
#  'pl',
#  'tel',
#  'n',
#  '-',
#  'lui',
#  'tenant',
#  '▁ter',
#  '▁ze',
#  'e',
#  '.']
